# %% [markdown]
# **Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose you have collected data on the amount of time students spend studying for an exam and their final exam scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.**

# %%
import pandas as pd
df = pd.DataFrame({
    'Time_Studied': [4,3,5,7,6],
    'Marks_Obtained': [60 ,45, 70, 90, 83]
})
df
# Out:
#    Time_Studied  Marks_Obtained
# 0             4              60
# 1             3              45
# 2             5              70
# 3             7              90
# 4             6              83

# %% [markdown]
# The formula for finding Pearson's correlation between both the variables is:

# %%
from IPython.display import Image, display

# URL of the image you want to display
image_url = "https://cdn1.byjus.com/wp-content/uploads/2019/06/word-image28.png"

# Display the image in the Colab notebook
display(Image(url=image_url))
# Out:
# <img src="https://cdn1.byjus.com/wp-content/uploads/2019/06/word-image28.png"/>

# %% [markdown]
# We can also find the Pearson's correlation using Python:

# %%
df.corr(method='pearson')
# Out:
#                 Time_Studied  Marks_Obtained
# Time_Studied        1.000000        0.993678
# Marks_Obtained      0.993678        1.000000

# %% [markdown]
# **Interpretation:**<br>
# The Pearson's correlation coefficients in the given results indicate a very strong positive correlation between the variables of "Time_Studied" and "Marks_Obtained".
#
# Both correlation coefficients are close to 1.000, which means that there is a very strong positive relationship between the two variables. This suggests that as "Time_Studied" increases, "Marks_Obtained" also increases.

# %% [markdown]
# **Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables. Suppose you have collected data on the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two variables and interpret the result.**

# %%
df = pd.DataFrame({
    'Sleep_Amount': [6, 7, 5, 8, 7, 6, 5, 9, 8, 7],
    'Job_Satisfaction': [8, 9, 4, 7, 6, 5, 3, 10, 9, 8]
})
df
# Out:
#    Sleep_Amount  Job_Satisfaction
# 0             6                 8
# 1             7                 9
# 2             5                 4
# 3             8                 7
# 4             7                 6
# 5             6                 5
# 6             5                 3
# 7             9                10
# 8             8                 9
# 9             7                 8

# %% [markdown]
# The formula for calculating Spearman's correlation coefficient between the two variables is:

# %%
from IPython.display import Image, display

# URL of the image you want to display
image_url = "https://editor.analyticsvidhya.com/uploads/78421Screenshot%202021-08-26%20235748.png"

# Display the image in the Colab notebook
display(Image(url=image_url))
# Out:
# <img src="https://editor.analyticsvidhya.com/uploads/78421Screenshot%202021-08-26%20235748.png"/>

# %% [markdown]
# We can also find the Pearson's correlation using Python:

# %%
df['Sleep_Amount'].corr(df['Job_Satisfaction'], method='spearman')
# Out:
# 0.7976045521851899

# %%
df.corr(method='spearman')
# Out:
#                   Sleep_Amount  Job_Satisfaction
# Sleep_Amount          1.000000          0.797605
# Job_Satisfaction      0.797605          1.000000

# %% [markdown]
# **Interpretation:**<br>
# The correlation coefficient between Sleep Amount and Job Satisfaction is 0.797605, which is close to +1. This indicates a strong positive monotonic correlation between these two variables.
#
# As the amount of sleep individuals get each night increases, their overall job satisfaction level tends to increase as well. Conversely, as the amount of sleep decreases, job satisfaction tends to decrease.

# %% [markdown]
# **Q3. Suppose you are conducting a study to examine the relationship between the number of hours of exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation between these two variables and compare the results.**
#
# To calculate the Pearson correlation coefficient and the Spearman's rank correlation between the number of hours of exercise per week and body mass index (BMI) in a sample of 50 adults, we need to have data for both variables.
#
# We can use Python to generate random data for both variables and then calculate the Pearson and Spearman's rank correlation between them:

# %%
import numpy as np
num_of_hours = np.random.normal(5, 2, 50)
bmi = np.random.normal(25, 5, 50)
df = pd.DataFrame({
    'num_of_hours': num_of_hours,
    'bmi': bmi
})
df.head()
# Out:
#    num_of_hours        bmi
# 0      5.808027  23.986439
# 1      3.491747  21.236888
# 2      0.934486  17.368999
# 3      6.696685  26.357032
# 4      3.047894  23.155736

# %% [markdown]
# **Pearson's Coefficient Correlation:**

# %%
df.corr(method='pearson')
# Out:
#               num_of_hours       bmi
# num_of_hours      1.000000  0.143311
# bmi               0.143311  1.000000

# %% [markdown]
# **Spearman's Rank Correlation:**

# %%
df.corr(method='spearman')
# Out:
#               num_of_hours       bmi
# num_of_hours      1.000000  0.147659
# bmi               0.147659  1.000000

# %% [markdown]
# **Results Comparison:**
#
# The Pearson correlation coefficient measures the linear relationship between two variables, and it ranges from -1 (perfect negative correlation) to +1 (perfect positive correlation), with 0 indicating no correlation. In this case, the Pearson correlation coefficient between num_of_hours and bmi is 0.143311, which indicates a weak positive correlation between the two variables.
#
# On the other hand, the Spearman correlation coefficient measures the monotonic relationship between two variables, which means it assesses the strength and direction of a relationship between two variables, without assuming any particular functional form of the relationship. It also ranges from -1 to +1, with 0 indicating no correlation. In this case, the Spearman correlation coefficient between num_of_hours and bmi is 0.147659, which also indicates a weak positive correlation between the two variables.

# %% [markdown]
# **Q4. A researcher is interested in examining the relationship between the number of hours individuals spend watching television per day and their level of physical activity. The researcher collected data on both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between these two variables.**
#
# To calculate the Pearson correlation coefficient between the number of hours individuals spend watching television per day and their level of physical activity of hours of exercise per week in a sample of 50 pariticipants, we need to have data for both variables.
#
# We can use Python to generate random data for both variables and then calculate the Pearson correlation coeffiecients:

# %%
num_of_hours = np.random.normal(6, 4, 50)
amount_of_activity= np.random.normal(10, 6, 50)
df = pd.DataFrame({
    'num_of_hours': num_of_hours,
    'physical_activity': amount_of_activity
})
df.head()
# Out:
#    num_of_hours  physical_activity
# 0      6.336518          19.288699
# 1     -2.057461          14.874294
# 2      2.919520          24.811856
# 3      3.179143          -2.942457
# 4      3.138373          14.372435

# %% [markdown]
# **Pearson's Coefficient Correlation:**

# %%
df.corr(method='pearson')
# Out:
#                    num_of_hours  physical_activity
# num_of_hours           1.000000           0.143047
# physical_activity      0.143047           1.000000

# %% [markdown]
# **Results Comparison:**
#
# The Pearson correlation coefficient measures the linear relationship between two variables, and it ranges from -1 (perfect negative correlation) to +1 (perfect positive correlation), with 0 indicating no correlation. In this case, the Pearson correlation coefficient between num_of_hours and physical_activities is 0.143047, which indicates a weak positive correlation between the two variables.

# %% [markdown]
# **Q5. A survey was conducted to examine the relationship between age and preference for a particular brand of soft drink. The survey results are shown below:**

# %%
df = pd.DataFrame({
    "Age(Years)": [25, 42, 37, 19, 31, 28],
    "Soft Drink Preference": ['Coke', 'Pepsi', 'Mountain Dew', 'Coke', 'Pepsi', 'Coke']
})
df
# Out:
#    Age(Years) Soft Drink Preference
# 0          25                  Coke
# 1          42                 Pepsi
# 2          37          Mountain Dew
# 3          19                  Coke
# 4          31                 Pepsi
# 5          28                  Coke

# %% [markdown]
# For finding Pearson correlation, we first need to convert the categorical variable to numerical variable. We can do so by encoding it:

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoded_col = encoder.fit_transform(df['Soft Drink Preference'])
df_encoded = pd.DataFrame(encoded_col, columns=['Soft Drink Preference Enc'])
df_new = pd.concat([df, df_encoded], axis=1)
df_new = df_new.drop('Soft Drink Preference', axis=1)
df_new
# Out:
#    Age(Years)  Soft Drink Preference Enc
# 0          25                          0
# 1          42                          2
# 2          37                          1
# 3          19                          0
# 4          31                          2
# 5          28                          0

# %% [markdown]
# **Pearson's Coefficient Correlation:**

# %%
df_new.corr(method='pearson')
# Out:
#                            Age(Years)  Soft Drink Preference Enc
# Age(Years)                   1.000000                   0.769175
# Soft Drink Preference Enc    0.769175                   1.000000

# %% [markdown]
# **Results Comparison:**
#
# The Pearson correlation coefficient measures the linear relationship between two variables, and it ranges from -1 (perfect negative correlation) to +1 (perfect positive correlation), with 0 indicating no correlation. In this case, the Pearson correlation coefficient between Age(Years) and Soft Drink Preference Enc  is 0.7691751415594738, which indicates a strong positive correlation between the two variables.

# %% [markdown]
# **Q6. A company is interested in examining the relationship between the number of sales calls made per day and the number of sales made per week. The company collected data on both variables from a sample of 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.**
#
# Rather than generating 30 random values for both the variables, I'm taking 10 values for each variable.

# %%
num_of_calls = [20, 30, 10, 40, 60, 80, 60, 50, 40, 100]
num_of_sales = [2, 3, 2, 5, 5, 6, 8, 5, 7, 20]
df = pd.DataFrame({
    'num_of_calls': num_of_calls,
    'num_of_sales': num_of_sales
})
df
# Out:
#    num_of_calls  num_of_sales
# 0            20             2
# 1            30             3
# 2            10             2
# 3            40             5
# 4            60             5
# 5            80             6
# 6            60             8
# 7            50             5
# 8            40             7
# 9           100            20

# %% [markdown]
# **Pearson's Coefficient Correlation:**

# %%
df.corr(method='pearson')
# Out:
#               num_of_calls  num_of_sales
# num_of_calls      1.000000      0.824008
# num_of_sales      0.824008      1.000000

# %% [markdown]
# **Spearman's Rank Correlation:**

# %%
df.corr(method='spearman')
# Out:
#               num_of_calls  num_of_sales
# num_of_calls      1.000000      0.835949
# num_of_sales      0.835949      1.000000

# %% [markdown]
# **Results Comparison:**
#
# The Pearson correlation coefficient measures the linear relationship between two variables, and it ranges from -1 (perfect negative correlation) to +1 (perfect positive correlation), with 0 indicating no correlation. In this case, the Pearson correlation coefficient between num_of_calls and num_of_sales is 0.824008, which indicates a strong positive correlation between the two variables.
#
# On the other hand, the Spearman correlation coefficient measures the monotonic relationship between two variables, which means it assesses the strength and direction of a relationship between two variables, without assuming any particular functional form of the relationship. It also ranges from -1 to +1, with 0 indicating no correlation. In this case, the Spearman correlation coefficient between num_of_calls and num_of_sales is 0.835949, which indicates a strong positive correlation between the two variables
